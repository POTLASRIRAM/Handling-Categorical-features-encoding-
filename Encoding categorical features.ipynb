# %% [markdown]
#  ### Ordinal Number encoding

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import datetime

# %%
data=[datetime.datetime.today()-datetime.timedelta(x) for x in range(0,15)]

# %%
data
# Out:
# [datetime.datetime(2020, 10, 17, 10, 38, 20, 449628),
#  datetime.datetime(2020, 10, 16, 10, 38, 20, 449628),
#  datetime.datetime(2020, 10, 15, 10, 38, 20, 449628),
#  datetime.datetime(2020, 10, 14, 10, 38, 20, 449628),
#  datetime.datetime(2020, 10, 13, 10, 38, 20, 449628),
#  datetime.datetime(2020, 10, 12, 10, 38, 20, 449628),
#  datetime.datetime(2020, 10, 11, 10, 38, 20, 449628),
#  datetime.datetime(2020, 10, 10, 10, 38, 20, 449628),
#  datetime.datetime(2020, 10, 9, 10, 38, 20, 449628),
#  datetime.datetime(2020, 10, 8, 10, 38, 20, 449628),
#  datetime.datetime(2020, 10, 7, 10, 38, 20, 449628),
#  datetime.datetime(2020, 10, 6, 10, 38, 20, 449628),
#  datetime.datetime(2020, 10, 5, 10, 38, 20, 449628),
#  datetime.datetime(2020, 10, 4, 10, 38, 20, 449628),
#  datetime.datetime(2020, 10, 3, 10, 38, 20, 449628)]

# %%
df=pd.DataFrame(data)

# %%
df.columns=['Day']

# %%
df
# Out:
#                           Day
# 0  2020-10-17 10:38:20.449628
# 1  2020-10-16 10:38:20.449628
# 2  2020-10-15 10:38:20.449628
# 3  2020-10-14 10:38:20.449628
# 4  2020-10-13 10:38:20.449628
# 5  2020-10-12 10:38:20.449628
# 6  2020-10-11 10:38:20.449628
# 7  2020-10-10 10:38:20.449628
# 8  2020-10-09 10:38:20.449628
# 9  2020-10-08 10:38:20.449628
# 10 2020-10-07 10:38:20.449628
# 11 2020-10-06 10:38:20.449628
# 12 2020-10-05 10:38:20.449628
# 13 2020-10-04 10:38:20.449628
# 14 2020-10-03 10:38:20.449628

# %%
df['Week_day']=df['Day'].dt.weekday

# %%
df
# Out:
#                           Day  Week_day
# 0  2020-10-17 10:38:20.449628         5
# 1  2020-10-16 10:38:20.449628         4
# 2  2020-10-15 10:38:20.449628         3
# 3  2020-10-14 10:38:20.449628         2
# 4  2020-10-13 10:38:20.449628         1
# 5  2020-10-12 10:38:20.449628         0
# 6  2020-10-11 10:38:20.449628         6
# 7  2020-10-10 10:38:20.449628         5
# 8  2020-10-09 10:38:20.449628         4
# 9  2020-10-08 10:38:20.449628         3
# 10 2020-10-07 10:38:20.449628         2
# 11 2020-10-06 10:38:20.449628         1
# 12 2020-10-05 10:38:20.449628         0
# 13 2020-10-04 10:38:20.449628         6
# 14 2020-10-03 10:38:20.449628         5

# %% [markdown]
# ### Count or frequency encoding

# %%
train_set = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data', header = None,index_col=None)

# %%
train_set.head()
# Out:
#    0                  1       2           3   4                    5   \
# 0  39          State-gov   77516   Bachelors  13        Never-married
# 1  50   Self-emp-not-inc   83311   Bachelors  13   Married-civ-spouse
# 2  38            Private  215646     HS-grad   9             Divorced
# 3  53            Private  234721        11th   7   Married-civ-spouse
# 4  28            Private  338409   Bachelors  13   Married-civ-spouse
#
#                    6               7       8        9     10  11  12  \
# 0        Adm-clerical   Not-in-family   White     Male  2174   0  40
# 1     Exec-managerial         Husband   White     Male     0   0  13
# 2   Handlers-cleaners   Not-in-family   White     Male     0   0  40
# 3   Handlers-cleaners         Husband   Black     Male     0   0  40
# 4      Prof-specialty            Wife   Black   Female     0   0  40
#
#                13      14
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %%
columns=[1,3,5,6,7,8,9,13]

# %%
df=train_set[columns]

# %%
df.columns=['Employment','Degree','Status','Designation','family_job','Race','Sex','Country']

# %%
df
# Out:
#               Employment       Degree               Status  \
# 0              State-gov    Bachelors        Never-married
# 1       Self-emp-not-inc    Bachelors   Married-civ-spouse
# 2                Private      HS-grad             Divorced
# 3                Private         11th   Married-civ-spouse
# 4                Private    Bachelors   Married-civ-spouse
# ...                  ...          ...                  ...
# 32556            Private   Assoc-acdm   Married-civ-spouse
# 32557            Private      HS-grad   Married-civ-spouse
# 32558            Private      HS-grad              Widowed
# 32559            Private      HS-grad        Never-married
# 32560       Self-emp-inc      HS-grad   Married-civ-spouse
#
#               Designation      family_job    Race      Sex         Country
# 0            Adm-clerical   Not-in-family   White     Male   United-States
# 1         Exec-managerial         Husband   White     Male   United-States
# ...

# %%
for feature in df.columns[:]:
    print(feature,":",len(df[feature].unique()),'labels')
# Out:
# Employment : 9 labels
# Degree : 16 labels
# Status : 7 labels
# Designation : 15 labels
# family_job : 6 labels
# Race : 5 labels
# Sex : 2 labels
# Country : 42 labels

# %%
df['Country'].value_counts().to_dict()
# Out:
# {' United-States': 29170,
#  ' Mexico': 643,
#  ' ?': 583,
#  ' Philippines': 198,
#  ' Germany': 137,
#  ' Canada': 121,
#  ' Puerto-Rico': 114,
#  ' El-Salvador': 106,
#  ' India': 100,
#  ' Cuba': 95,
#  ' England': 90,
#  ' Jamaica': 81,
#  ' South': 80,
#  ' China': 75,
#  ' Italy': 73,
#  ' Dominican-Republic': 70,
#  ' Vietnam': 67,
#  ' Guatemala': 64,
#  ' Japan': 62,
#  ' Poland': 60,
#  ' Columbia': 59,
#  ' Taiwan': 51,
#  ' Haiti': 44,
#  ' Iran': 43,
#  ' Portugal': 37,
#  ' Nicaragua': 34,
#  ' Peru': 31,
#  ' Greece': 29,
#  ' France': 29,
#  ' Ecuador': 28,
#  ' Ireland': 24,
#  ' Hong': 20,
#  ' Trinadad&Tobago': 19,
#  ' Cambodia': 19,
#  ' Thailand': 18,
#  ' Laos': 18,
#  ' Yugoslavia': 16,
#  ' Outlying-US(Guam-USVI-etc)': 14,
#  ' Hungary': 13,
#  ' Honduras': 13,
#  ' Scotland': 12,
#  ' Holand-Netherlands': 1}

# %%
country={'Country':{' United-States': 29170,
 ' Mexico': 643,
 ' ?': 583,
 ' Philippines': 198,
 ' Germany': 137,
 ' Canada': 121,
 ' Puerto-Rico': 114,
 ' El-Salvador': 106,
 ' India': 100,
 ' Cuba': 95,
 ' England': 90,
 ' Jamaica': 81,
 ' South': 80,
 ' China': 75,
 ' Italy': 73,
 ' Dominican-Republic': 70,
 ' Vietnam': 67,
 ' Guatemala': 64,
 ' Japan': 62,
 ' Poland': 60,
 ' Columbia': 59,
 ' Taiwan': 51,
 ' Haiti': 44,
 ' Iran': 43,
 ' Portugal': 37,
 ' Nicaragua': 34,
 ' Peru': 31,
 ' Greece': 29,
 ' France': 29,
 ' Ecuador': 28,
 ' Ireland': 24,
 ' Hong': 20,
 ' Trinadad&Tobago': 19,
 ' Cambodia': 19,
 ' Thailand': 18,
 ' Laos': 18,
 ' Yugoslavia': 16,
 ' Outlying-US(Guam-USVI-etc)': 14,
 ' Hungary': 13,
 ' Honduras': 13,
 ' Scotland': 12,
 ' Holand-Netherlands': 1}}

# %%
df.replace(country,inplace=True)
# Out:
# C:\Users\potla\Anaconda3\lib\site-packages\pandas\core\generic.py:6662: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   res[c] = res[c].replace(

# %%
df
# Out:
#               Employment       Degree               Status  \
# 0              State-gov    Bachelors        Never-married
# 1       Self-emp-not-inc    Bachelors   Married-civ-spouse
# 2                Private      HS-grad             Divorced
# 3                Private         11th   Married-civ-spouse
# 4                Private    Bachelors   Married-civ-spouse
# ...                  ...          ...                  ...
# 32556            Private   Assoc-acdm   Married-civ-spouse
# 32557            Private      HS-grad   Married-civ-spouse
# 32558            Private      HS-grad              Widowed
# 32559            Private      HS-grad        Never-married
# 32560       Self-emp-inc      HS-grad   Married-civ-spouse
#
#               Designation      family_job    Race      Sex  Country
# 0            Adm-clerical   Not-in-family   White     Male    29170
# 1         Exec-managerial         Husband   White     Male    29170
# ...

# %%
df['Country'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Target guided encoding

# %%
df=pd.read_csv('D:\Feature engineering techniques\Handlng missing values day-1\Dataset.csv',usecols=['Survived','Cabin'])

# %%
df
# Out:
#      Survived Cabin
# 0           0   NaN
# 1           1   C85
# 2           1   NaN
# 3           1  C123
# 4           0   NaN
# ..        ...   ...
# 886         0   NaN
# 887         1   B42
# 888         0   NaN
# 889         1  C148
# 890         0   NaN
#
# [891 rows x 2 columns]

# %%
df['Cabin'].fillna("Missing",inplace=True)

# %%
df
# Out:
#      Survived    Cabin
# 0           0  Missing
# 1           1      C85
# 2           1  Missing
# 3           1     C123
# 4           0  Missing
# ..        ...      ...
# 886         0  Missing
# 887         1      B42
# 888         0  Missing
# 889         1     C148
# 890         0  Missing
#
# [891 rows x 2 columns]

# %%
df['Cabin']=df['Cabin'].astype(str).str[0]

# %%
df
# Out:
#      Survived Cabin
# 0           0     M
# 1           1     C
# 2           1     M
# 3           1     C
# 4           0     M
# ..        ...   ...
# 886         0     M
# 887         1     B
# 888         0     M
# 889         1     C
# 890         0     M
#
# [891 rows x 2 columns]

# %%
df['Cabin'].value_counts()
# Out:
# M    687
# C     59
# B     47
# D     33
# E     32
# A     15
# F     13
# G      4
# T      1
# Name: Cabin, dtype: int64

# %%
df.groupby(['Cabin'])['Survived'].mean()
# Out:
# Cabin
# A    0.466667
# B    0.744681
# C    0.593220
# D    0.757576
# E    0.750000
# F    0.615385
# G    0.500000
# M    0.299854
# T    0.000000
# Name: Survived, dtype: float64

# %%
cabin={'Cabin':{'T':0,'M':1,'A':2,'G':3,'C':4,'F':5,'B':6,'E':7,'D':8}}

# %%
df.replace(cabin,inplace=True)

# %%
df
# Out:
#      Survived  Cabin
# 0           0      1
# 1           1      4
# 2           1      1
# 3           1      4
# 4           0      1
# ..        ...    ...
# 886         0      1
# 887         1      6
# 888         0      1
# 889         1      4
# 890         0      1
#
# [891 rows x 2 columns]
